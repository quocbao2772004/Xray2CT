# %%
import numpy as np
import matplotlib.pyplot as plt

data = np.load(r"D:\my_dataset\LIDC-IDRI-0146\LIDC-IDRI-0146.npy")

for i in range(data.shape[0]): 
    plt.imshow(data[i], cmap='gray')
    plt.title(f'Slice {i}')
    plt.axis('off')
    plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

data = np.load(r"D:\data_asfloat32\LIDC-IDRI-0029\LIDC-IDRI-0029_drrFrontal.npy")
if data.ndim == 3:
    plt.imshow(data[:, :, 0], cmap='gray')
else:
    plt.imshow(data, cmap='gray')

plt.colorbar()  
plt.title('Visualizing')
plt.axis('off')  
plt.show()
